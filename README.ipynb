# %% [markdown]
# ## litbank
#
# Source: https://github.com/dbamman/litbank
#
# Description:
#
# - 大量英文小说
# - 实体标注
# - 共指小姐
# - 事件注释

# %% [markdown]
# ## CMU Movie Summary Corpus
#
# Source: http://www.cs.cmu.edu/~ark/personas/
#
# ## wikiplots
